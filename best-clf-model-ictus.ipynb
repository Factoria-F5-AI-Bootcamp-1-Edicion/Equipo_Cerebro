# %%
import numpy as np 
import pandas as pd

# %%
df_ros = pd.read_csv('../input/ictus-evaluation/ros.csv')
df_ros
# Out:
#            gridSearch  accu_std  accu_mod  acc_test  acc_train  overfitting %  \
# 0                 SVC  0.793173  0.946674  0.886546   0.977693      10.281081
# 1  LogisticRegression  0.770080  0.777851  0.770080   0.777983       1.026228
# 2       DecissionTree  0.921687  0.799367  0.732932   0.806230      10.000723
# 3                 KNN  0.861446  0.965945  0.916667   1.000000       9.090909
# 4    GradientBoosting  0.824297  0.994456  0.943775   1.000000       5.957447
# 5        RandomForest  0.941767  0.990496  0.941767   1.000000       6.183369
# 6            AdaBoost  0.770080  0.813622  0.765060   0.817582       6.865028
# 7                 XGB  0.931727  0.980201  0.925703   1.000000       8.026030
# 8            CatBoost  0.919679  0.908263  0.857430   0.940074       9.638597
# 9                LGBM  0.915663  0.839364  0.772088   0.848469       9.892714
#
#      recall        f1  precission  balanced_accucracy       ROC
# 0  0.058824  0.050420    0.044118            0.495020  0.495020
# 1  0.843137  0.273016    0.162879            0.804637  0.804637
# 2  0.666667  0.203593    0.120141            0.701587  0.701587
# 3  0.078431  0.087912    0.100000            0.520168  0.520168
# 4  0.019608  0.034483    0.142857            0.506629  0.506629
# 5  0.039216  0.064516    0.181818            0.514846  0.514846
# 6  0.803922  0.259494    0.154717            0.783442  0.783442
# 7  0.019608  0.026316    0.040000            0.497106  0.497106
# 8  0.509804  0.268041    0.181818            0.692997  0.692997
# 9  0.705882  0.240803    0.145161            0.740772  0.740772

# %%
df_rus = pd.read_csv('../input/ictus-evaluation/rus.csv')
df_rus
# Out:
#            gridSearch  accu_std  accu_mod  acc_test  acc_train  overfitting %  \
# 0                 SVC  0.658635  0.794872  0.734940   0.817949      11.294662
# 1  LogisticRegression  0.730924  0.779487  0.738956   0.800000       8.260870
# 2       DecissionTree  0.683735  0.782051  0.695783   0.792308      13.872794
# 3                 KNN  0.687751  0.684615  0.610442   0.715385      17.191296
# 4    GradientBoosting  0.726908  0.794872  0.696787   0.802564      15.180669
# 5        RandomForest  0.725904  0.776923  0.705823   1.000000      41.678521
# 6            AdaBoost  0.712851  0.784615  0.695783   0.792308      13.872794
# 7                 XGB  0.709839  0.797436  0.708835   0.802564      13.222924
# 8            CatBoost  0.717871  0.792308  0.679719   0.800000      17.695716
# 9                LGBM  0.708835  0.746154  0.709839   0.792308      11.617887
#
#      recall        f1  precission  balanced_accucracy       ROC
# 0  0.862745  0.250000    0.146179            0.795394  0.795394
# 1  0.862745  0.252874    0.148148            0.797510  0.797510
# 2  0.882353  0.229008    0.131579            0.784034  0.784034
# 3  0.647059  0.145374    0.081886            0.627762  0.627762
# 4  0.862745  0.225641    0.129794            0.775288  0.775288
# 5  0.803922  0.218667    0.126543            0.752225  0.752225
# 6  0.882353  0.229008    0.131579            0.784034  0.784034
# 7  0.882353  0.236842    0.136778            0.790912  0.790912
# 8  0.882353  0.220049    0.125698            0.775568  0.775568
# 9  0.882353  0.237467    0.137195            0.791441  0.791441

# %%
df_smote = pd.read_csv('../input/ictus-evaluation/sm.csv')
df_smote
# Out:
#            gridSearch  accu_std  accu_mod  acc_test  acc_train  overfitting %  \
# 0                 SVC  0.859438  0.917987  0.900602   0.969472       7.647052
# 1  LogisticRegression  0.831325  0.776073  0.832329   0.779043       6.402083
# 2       DecissionTree  0.875502  0.800330  0.830321   0.821122       1.107905
# 3                 KNN  0.852410  0.915677  0.885542   1.000000      12.925170
# 4    GradientBoosting  0.899598  0.950330  0.931727   1.000000       7.327586
# 5        RandomForest  0.918675  0.935479  0.914659   1.000000       9.330406
# 6            AdaBoost  0.840361  0.845875  0.865462   0.853465       1.386139
# 7                 XGB  0.931727  0.942244  0.932731   0.996535       6.840529
# 8            CatBoost  0.930723  0.872112  0.876506   0.905941       3.358171
# 9                LGBM  0.924699  0.625083  0.948795   0.625083      34.118288
#
#      recall        f1  precission  balanced_accucracy       ROC
# 0  0.078431  0.074766    0.071429            0.511702  0.511702
# 1  0.725490  0.307054    0.194737            0.781793  0.781793
# 2  0.686275  0.292887    0.186170            0.762185  0.762185
# 3  0.078431  0.065574    0.056338            0.503766  0.503766
# 4  0.039216  0.055556    0.095238            0.509555  0.509555
# 5  0.098039  0.105263    0.113636            0.528385  0.528385
# 6  0.450980  0.255556    0.178295            0.669406  0.669406
# 7  0.078431  0.106667    0.166667            0.528634  0.528634
# 8  0.333333  0.216561    0.160377            0.619577  0.619577
# 9  0.000000  0.000000    0.000000            0.500000  0.500000

# %%
#df_smote_tomek = pd.read_csv('../input/ictus-data/sm_tek.csv')
#df_smote_tomek

# %%
df_cnn = pd.read_csv('../input/ictus-evaluation/undersample.csv')
df_cnn
# Out:
#            gridSearch  accu_std  accu_mod  acc_test  acc_train  overfitting %  \
# 0                 SVC  0.948795  0.736054  0.948795   0.733333      22.708995
# 1  LogisticRegression  0.947791  0.737415  0.939759   0.734694      21.821036
# 2       DecissionTree  0.839357  0.734694  0.948795   0.734694      22.565598
# 3                 KNN  0.933735  0.734694  0.949799   0.742857      21.787979
# 4    GradientBoosting  0.924699  0.736054  0.948795   0.734694      22.565598
# 5        RandomForest  0.931727  0.703401  0.932731   1.000000       7.212056
# 6            AdaBoost  0.916667  0.734694  0.948795   0.734694      22.565598
# 7                 XGB  0.903614  0.736054  0.948795   0.734694      22.565598
# 8            CatBoost  0.930723  0.744218  0.944779   0.760544      19.500314
# 9                LGBM  0.913655  0.734694  0.948795   0.734694      22.565598
#
#      recall        f1  precission  balanced_accucracy       ROC
# 0  0.000000  0.000000    0.000000            0.500000  0.500000
# 1  0.078431  0.117647    0.235294            0.532337  0.532337
# 2  0.000000  0.000000    0.000000            0.500000  0.500000
# 3  0.039216  0.074074    0.666667            0.519079  0.519079
# 4  0.000000  0.000000    0.000000            0.500000  0.500000
# 5  0.039216  0.056338    0.100000            0.510084  0.510084
# 6  0.000000  0.000000    0.000000            0.500000  0.500000
# 7  0.000000  0.000000    0.000000            0.500000  0.500000
# 8  0.019608  0.035088    0.166667            0.507158  0.507158
# 9  0.000000  0.000000    0.000000            0.500000  0.500000

# %%
df_near_miss = pd.read_csv('../input/ictus-evaluation/nm.csv')
df_near_miss
# Out:
#            gridSearch  accu_std  accu_mod  acc_test  acc_train  overfitting %  \
# 0                 SVC  0.274096  0.841026  0.255020   0.871795     241.853422
# 1  LogisticRegression  0.371486  0.833333  0.374498   0.828205     121.150753
# 2       DecissionTree  0.286145  0.782051  0.390562   0.866667     121.902314
# 3                 KNN  0.366466  0.782051  0.290161   0.887179     205.754591
# 4    GradientBoosting  0.299197  0.856410  0.251004   0.997436     297.378462
# 5        RandomForest  0.227912  0.846154  0.248996   1.000000     301.612903
# 6            AdaBoost  0.407631  0.823077  0.554217   0.828205      49.437012
# 7                 XGB  0.336345  0.841026  0.383534   0.882051     129.979863
# 8            CatBoost  0.278112  0.835897  0.349398   0.866667     148.045977
# 9                LGBM  0.360442  0.779487  0.439759   0.820513      86.582367
#
#      recall        f1  precission  balanced_accucracy       ROC
# 0  0.823529  0.101695    0.054194            0.523934  0.523934
# 1  0.725490  0.106169    0.057276            0.540523  0.540523
# 2  0.607843  0.092676    0.050162            0.493340  0.493340
# 3  0.666667  0.087742    0.046961            0.468254  0.468254
# 4  0.843137  0.103365    0.055058            0.531092  0.531092
# 5  0.823529  0.100962    0.053777            0.520759  0.520759
# 6  0.627451  0.125984    0.070022            0.588858  0.588858
# 7  0.705882  0.104956    0.056693            0.536010  0.536010
# 8  0.666667  0.094972    0.051128            0.499471  0.499471
# 9  0.725490  0.117089    0.063683            0.574914  0.574914

# %%
#df_sample_weight = pd.read_csv('../input/ictus-data/undersample.csv')
#df_sample_weight

# %%
#df_balance_bagging = pd.read_csv('../input/ictus-data/undersample.csv')
#df_balance_bagging

# %%
df_ros['balance_method'] = 'ros'
df_rus['balance_method'] = 'rus'
df_smote['balance_method'] = 'smote'
#df_smote_tomek['balance_method'] = 'smote_tomek'
df_cnn['balance_method'] = 'condensed_nearest'
df_near_miss['balance_method'] = 'near_miss'
#df_sample_weight['balance_method'] = 'sample_weight'
#df_balance_bagging['balance_method'] = 'balance_bagging'

# %%
metricas_balanceo = pd.concat([df_ros, df_rus, df_smote , df_cnn , df_near_miss ])
metricas_balanceo
# Out:
#            gridSearch  accu_std  accu_mod  acc_test  acc_train  overfitting %  \
# 0                 SVC  0.793173  0.946674  0.886546   0.977693      10.281081
# 1  LogisticRegression  0.770080  0.777851  0.770080   0.777983       1.026228
# 2       DecissionTree  0.921687  0.799367  0.732932   0.806230      10.000723
# 3                 KNN  0.861446  0.965945  0.916667   1.000000       9.090909
# 4    GradientBoosting  0.824297  0.994456  0.943775   1.000000       5.957447
# 5        RandomForest  0.941767  0.990496  0.941767   1.000000       6.183369
# 6            AdaBoost  0.770080  0.813622  0.765060   0.817582       6.865028
# 7                 XGB  0.931727  0.980201  0.925703   1.000000       8.026030
# 8            CatBoost  0.919679  0.908263  0.857430   0.940074       9.638597
# 9                LGBM  0.915663  0.839364  0.772088   0.848469       9.892714
# 0                 SVC  0.658635  0.794872  0.734940   0.817949      11.294662
# 1  LogisticRegression  0.730924  0.779487  0.738956   0.800000       8.260870
# 2       DecissionTree  0.683735  0.782051  0.695783   0.792308      13.872794
# 3                 KNN  0.687751  0.684615  0.610442   0.715385      17.191296
# 4    GradientBoosting  0.726908  0.794872  0.696787   0.802564      15.180669
# 5        RandomForest  0.725904  0.776923  0.705823   1.000000      41.678521
# 6            AdaBoost  0.712851  0.784615  0.695783   0.792308      13.872794
# 7                 XGB  0.709839  0.797436  0.708835   0.802564      13.222924
# 8            CatBoost  0.717871  0.792308  0.679719   0.800000      17.695716
# 9                LGBM  0.708835  0.746154  0.709839   0.792308      11.617887
# 0                 SVC  0.859438  0.917987  0.900602   0.969472       7.647052
# 1  LogisticRegression  0.831325  0.776073  0.832329   0.779043       6.402083
# 2       DecissionTree  0.875502  0.800330  0.830321   0.821122       1.107905
# 3                 KNN  0.852410  0.915677  0.885542   1.000000      12.925170
# 4    GradientBoosting  0.899598  0.950330  0.931727   1.000000       7.327586
# 5        RandomForest  0.918675  0.935479  0.914659   1.000000       9.330406
# 6            AdaBoost  0.840361  0.845875  0.865462   0.853465       1.386139
# 7                 XGB  0.931727  0.942244  0.932731   0.996535       6.840529
# 8            CatBoost  0.930723  0.872112  0.876506   0.905941       3.358171
# 9                LGBM  0.924699  0.625083  0.948795   0.625083      34.118288
# 0                 SVC  0.948795  0.736054  0.948795   0.733333      22.708995
# 1  LogisticRegression  0.947791  0.737415  0.939759   0.734694      21.821036
# 2       DecissionTree  0.839357  0.734694  0.948795   0.734694      22.565598
# 3                 KNN  0.933735  0.734694  0.949799   0.742857      21.787979
# 4    GradientBoosting  0.924699  0.736054  0.948795   0.734694      22.565598
# 5        RandomForest  0.931727  0.703401  0.932731   1.000000       7.212056
# 6            AdaBoost  0.916667  0.734694  0.948795   0.734694      22.565598
# 7                 XGB  0.903614  0.736054  0.948795   0.734694      22.565598
# 8            CatBoost  0.930723  0.744218  0.944779   0.760544      19.500314
# 9                LGBM  0.913655  0.734694  0.948795   0.734694      22.565598
# 0                 SVC  0.274096  0.841026  0.255020   0.871795     241.853422
# 1  LogisticRegression  0.371486  0.833333  0.374498   0.828205     121.150753
# 2       DecissionTree  0.286145  0.782051  0.390562   0.866667     121.902314
# 3                 KNN  0.366466  0.782051  0.290161   0.887179     205.754591
# 4    GradientBoosting  0.299197  0.856410  0.251004   0.997436     297.378462
# 5        RandomForest  0.227912  0.846154  0.248996   1.000000     301.612903
# 6            AdaBoost  0.407631  0.823077  0.554217   0.828205      49.437012
# 7                 XGB  0.336345  0.841026  0.383534   0.882051     129.979863
# 8            CatBoost  0.278112  0.835897  0.349398   0.866667     148.045977
# 9                LGBM  0.360442  0.779487  0.439759   0.820513      86.582367
#
#      recall        f1  precission  balanced_accucracy       ROC  \
# 0  0.058824  0.050420    0.044118            0.495020  0.495020
# 1  0.843137  0.273016    0.162879            0.804637  0.804637
# 2  0.666667  0.203593    0.120141            0.701587  0.701587
# 3  0.078431  0.087912    0.100000            0.520168  0.520168
# 4  0.019608  0.034483    0.142857            0.506629  0.506629
# 5  0.039216  0.064516    0.181818            0.514846  0.514846
# 6  0.803922  0.259494    0.154717            0.783442  0.783442
# 7  0.019608  0.026316    0.040000            0.497106  0.497106
# 8  0.509804  0.268041    0.181818            0.692997  0.692997
# 9  0.705882  0.240803    0.145161            0.740772  0.740772
# 0  0.862745  0.250000    0.146179            0.795394  0.795394
# 1  0.862745  0.252874    0.148148            0.797510  0.797510
# 2  0.882353  0.229008    0.131579            0.784034  0.784034
# 3  0.647059  0.145374    0.081886            0.627762  0.627762
# 4  0.862745  0.225641    0.129794            0.775288  0.775288
# 5  0.803922  0.218667    0.126543            0.752225  0.752225
# 6  0.882353  0.229008    0.131579            0.784034  0.784034
# 7  0.882353  0.236842    0.136778            0.790912  0.790912
# 8  0.882353  0.220049    0.125698            0.775568  0.775568
# 9  0.882353  0.237467    0.137195            0.791441  0.791441
# 0  0.078431  0.074766    0.071429            0.511702  0.511702
# 1  0.725490  0.307054    0.194737            0.781793  0.781793
# 2  0.686275  0.292887    0.186170            0.762185  0.762185
# 3  0.078431  0.065574    0.056338            0.503766  0.503766
# 4  0.039216  0.055556    0.095238            0.509555  0.509555
# 5  0.098039  0.105263    0.113636            0.528385  0.528385
# 6  0.450980  0.255556    0.178295            0.669406  0.669406
# 7  0.078431  0.106667    0.166667            0.528634  0.528634
# 8  0.333333  0.216561    0.160377            0.619577  0.619577
# 9  0.000000  0.000000    0.000000            0.500000  0.500000
# 0  0.000000  0.000000    0.000000            0.500000  0.500000
# 1  0.078431  0.117647    0.235294            0.532337  0.532337
# 2  0.000000  0.000000    0.000000            0.500000  0.500000
# 3  0.039216  0.074074    0.666667            0.519079  0.519079
# 4  0.000000  0.000000    0.000000            0.500000  0.500000
# 5  0.039216  0.056338    0.100000            0.510084  0.510084
# 6  0.000000  0.000000    0.000000            0.500000  0.500000
# 7  0.000000  0.000000    0.000000            0.500000  0.500000
# 8  0.019608  0.035088    0.166667            0.507158  0.507158
# 9  0.000000  0.000000    0.000000            0.500000  0.500000
# 0  0.823529  0.101695    0.054194            0.523934  0.523934
# 1  0.725490  0.106169    0.057276            0.540523  0.540523
# 2  0.607843  0.092676    0.050162            0.493340  0.493340
# 3  0.666667  0.087742    0.046961            0.468254  0.468254
# 4  0.843137  0.103365    0.055058            0.531092  0.531092
# 5  0.823529  0.100962    0.053777            0.520759  0.520759
# 6  0.627451  0.125984    0.070022            0.588858  0.588858
# 7  0.705882  0.104956    0.056693            0.536010  0.536010
# 8  0.666667  0.094972    0.051128            0.499471  0.499471
# 9  0.725490  0.117089    0.063683            0.574914  0.574914
#
#       balance_method
# 0                ros
# 1                ros
# 2                ros
# 3                ros
# 4                ros
# 5                ros
# 6                ros
# 7                ros
# 8                ros
# 9                ros
# 0                rus
# 1                rus
# 2                rus
# 3                rus
# 4                rus
# 5                rus
# 6                rus
# 7                rus
# 8                rus
# 9                rus
# 0              smote
# 1              smote
# 2              smote
# 3              smote
# 4              smote
# 5              smote
# 6              smote
# 7              smote
# 8              smote
# 9              smote
# 0  condensed_nearest
# 1  condensed_nearest
# 2  condensed_nearest
# 3  condensed_nearest
# 4  condensed_nearest
# 5  condensed_nearest
# 6  condensed_nearest
# 7  condensed_nearest
# 8  condensed_nearest
# 9  condensed_nearest
# 0          near_miss
# 1          near_miss
# 2          near_miss
# 3          near_miss
# 4          near_miss
# 5          near_miss
# 6          near_miss
# 7          near_miss
# 8          near_miss
# 9          near_miss

# %%
metricas_balanceo.reset_index(inplace=True)
metricas_balanceo
# Out:
#     index          gridSearch  accu_std  accu_mod  acc_test  acc_train  \
# 0       0                 SVC  0.793173  0.946674  0.886546   0.977693
# 1       1  LogisticRegression  0.770080  0.777851  0.770080   0.777983
# 2       2       DecissionTree  0.921687  0.799367  0.732932   0.806230
# 3       3                 KNN  0.861446  0.965945  0.916667   1.000000
# 4       4    GradientBoosting  0.824297  0.994456  0.943775   1.000000
# 5       5        RandomForest  0.941767  0.990496  0.941767   1.000000
# 6       6            AdaBoost  0.770080  0.813622  0.765060   0.817582
# 7       7                 XGB  0.931727  0.980201  0.925703   1.000000
# 8       8            CatBoost  0.919679  0.908263  0.857430   0.940074
# 9       9                LGBM  0.915663  0.839364  0.772088   0.848469
# 10      0                 SVC  0.658635  0.794872  0.734940   0.817949
# 11      1  LogisticRegression  0.730924  0.779487  0.738956   0.800000
# 12      2       DecissionTree  0.683735  0.782051  0.695783   0.792308
# 13      3                 KNN  0.687751  0.684615  0.610442   0.715385
# 14      4    GradientBoosting  0.726908  0.794872  0.696787   0.802564
# 15      5        RandomForest  0.725904  0.776923  0.705823   1.000000
# 16      6            AdaBoost  0.712851  0.784615  0.695783   0.792308
# 17      7                 XGB  0.709839  0.797436  0.708835   0.802564
# 18      8            CatBoost  0.717871  0.792308  0.679719   0.800000
# 19      9                LGBM  0.708835  0.746154  0.709839   0.792308
# 20      0                 SVC  0.859438  0.917987  0.900602   0.969472
# 21      1  LogisticRegression  0.831325  0.776073  0.832329   0.779043
# 22      2       DecissionTree  0.875502  0.800330  0.830321   0.821122
# 23      3                 KNN  0.852410  0.915677  0.885542   1.000000
# 24      4    GradientBoosting  0.899598  0.950330  0.931727   1.000000
# 25      5        RandomForest  0.918675  0.935479  0.914659   1.000000
# 26      6            AdaBoost  0.840361  0.845875  0.865462   0.853465
# 27      7                 XGB  0.931727  0.942244  0.932731   0.996535
# 28      8            CatBoost  0.930723  0.872112  0.876506   0.905941
# 29      9                LGBM  0.924699  0.625083  0.948795   0.625083
# 30      0                 SVC  0.948795  0.736054  0.948795   0.733333
# 31      1  LogisticRegression  0.947791  0.737415  0.939759   0.734694
# 32      2       DecissionTree  0.839357  0.734694  0.948795   0.734694
# 33      3                 KNN  0.933735  0.734694  0.949799   0.742857
# 34      4    GradientBoosting  0.924699  0.736054  0.948795   0.734694
# 35      5        RandomForest  0.931727  0.703401  0.932731   1.000000
# 36      6            AdaBoost  0.916667  0.734694  0.948795   0.734694
# 37      7                 XGB  0.903614  0.736054  0.948795   0.734694
# 38      8            CatBoost  0.930723  0.744218  0.944779   0.760544
# 39      9                LGBM  0.913655  0.734694  0.948795   0.734694
# 40      0                 SVC  0.274096  0.841026  0.255020   0.871795
# 41      1  LogisticRegression  0.371486  0.833333  0.374498   0.828205
# 42      2       DecissionTree  0.286145  0.782051  0.390562   0.866667
# 43      3                 KNN  0.366466  0.782051  0.290161   0.887179
# 44      4    GradientBoosting  0.299197  0.856410  0.251004   0.997436
# 45      5        RandomForest  0.227912  0.846154  0.248996   1.000000
# 46      6            AdaBoost  0.407631  0.823077  0.554217   0.828205
# 47      7                 XGB  0.336345  0.841026  0.383534   0.882051
# 48      8            CatBoost  0.278112  0.835897  0.349398   0.866667
# 49      9                LGBM  0.360442  0.779487  0.439759   0.820513
#
#     overfitting %    recall        f1  precission  balanced_accucracy  \
# 0       10.281081  0.058824  0.050420    0.044118            0.495020
# 1        1.026228  0.843137  0.273016    0.162879            0.804637
# 2       10.000723  0.666667  0.203593    0.120141            0.701587
# 3        9.090909  0.078431  0.087912    0.100000            0.520168
# 4        5.957447  0.019608  0.034483    0.142857            0.506629
# 5        6.183369  0.039216  0.064516    0.181818            0.514846
# 6        6.865028  0.803922  0.259494    0.154717            0.783442
# 7        8.026030  0.019608  0.026316    0.040000            0.497106
# 8        9.638597  0.509804  0.268041    0.181818            0.692997
# 9        9.892714  0.705882  0.240803    0.145161            0.740772
# 10      11.294662  0.862745  0.250000    0.146179            0.795394
# 11       8.260870  0.862745  0.252874    0.148148            0.797510
# 12      13.872794  0.882353  0.229008    0.131579            0.784034
# 13      17.191296  0.647059  0.145374    0.081886            0.627762
# 14      15.180669  0.862745  0.225641    0.129794            0.775288
# 15      41.678521  0.803922  0.218667    0.126543            0.752225
# 16      13.872794  0.882353  0.229008    0.131579            0.784034
# 17      13.222924  0.882353  0.236842    0.136778            0.790912
# 18      17.695716  0.882353  0.220049    0.125698            0.775568
# 19      11.617887  0.882353  0.237467    0.137195            0.791441
# 20       7.647052  0.078431  0.074766    0.071429            0.511702
# 21       6.402083  0.725490  0.307054    0.194737            0.781793
# 22       1.107905  0.686275  0.292887    0.186170            0.762185
# 23      12.925170  0.078431  0.065574    0.056338            0.503766
# 24       7.327586  0.039216  0.055556    0.095238            0.509555
# 25       9.330406  0.098039  0.105263    0.113636            0.528385
# 26       1.386139  0.450980  0.255556    0.178295            0.669406
# 27       6.840529  0.078431  0.106667    0.166667            0.528634
# 28       3.358171  0.333333  0.216561    0.160377            0.619577
# 29      34.118288  0.000000  0.000000    0.000000            0.500000
# 30      22.708995  0.000000  0.000000    0.000000            0.500000
# 31      21.821036  0.078431  0.117647    0.235294            0.532337
# 32      22.565598  0.000000  0.000000    0.000000            0.500000
# 33      21.787979  0.039216  0.074074    0.666667            0.519079
# 34      22.565598  0.000000  0.000000    0.000000            0.500000
# 35       7.212056  0.039216  0.056338    0.100000            0.510084
# 36      22.565598  0.000000  0.000000    0.000000            0.500000
# 37      22.565598  0.000000  0.000000    0.000000            0.500000
# 38      19.500314  0.019608  0.035088    0.166667            0.507158
# 39      22.565598  0.000000  0.000000    0.000000            0.500000
# 40     241.853422  0.823529  0.101695    0.054194            0.523934
# 41     121.150753  0.725490  0.106169    0.057276            0.540523
# 42     121.902314  0.607843  0.092676    0.050162            0.493340
# 43     205.754591  0.666667  0.087742    0.046961            0.468254
# 44     297.378462  0.843137  0.103365    0.055058            0.531092
# 45     301.612903  0.823529  0.100962    0.053777            0.520759
# 46      49.437012  0.627451  0.125984    0.070022            0.588858
# 47     129.979863  0.705882  0.104956    0.056693            0.536010
# 48     148.045977  0.666667  0.094972    0.051128            0.499471
# 49      86.582367  0.725490  0.117089    0.063683            0.574914
#
#          ROC     balance_method
# 0   0.495020                ros
# 1   0.804637                ros
# 2   0.701587                ros
# 3   0.520168                ros
# 4   0.506629                ros
# 5   0.514846                ros
# 6   0.783442                ros
# 7   0.497106                ros
# 8   0.692997                ros
# 9   0.740772                ros
# 10  0.795394                rus
# 11  0.797510                rus
# 12  0.784034                rus
# 13  0.627762                rus
# 14  0.775288                rus
# 15  0.752225                rus
# 16  0.784034                rus
# 17  0.790912                rus
# 18  0.775568                rus
# 19  0.791441                rus
# 20  0.511702              smote
# 21  0.781793              smote
# 22  0.762185              smote
# 23  0.503766              smote
# 24  0.509555              smote
# 25  0.528385              smote
# 26  0.669406              smote
# 27  0.528634              smote
# 28  0.619577              smote
# 29  0.500000              smote
# 30  0.500000  condensed_nearest
# 31  0.532337  condensed_nearest
# 32  0.500000  condensed_nearest
# 33  0.519079  condensed_nearest
# 34  0.500000  condensed_nearest
# 35  0.510084  condensed_nearest
# 36  0.500000  condensed_nearest
# 37  0.500000  condensed_nearest
# 38  0.507158  condensed_nearest
# 39  0.500000  condensed_nearest
# 40  0.523934          near_miss
# 41  0.540523          near_miss
# 42  0.493340          near_miss
# 43  0.468254          near_miss
# 44  0.531092          near_miss
# 45  0.520759          near_miss
# 46  0.588858          near_miss
# 47  0.536010          near_miss
# 48  0.499471          near_miss
# 49  0.574914          near_miss

# %%
metricas_balanceo.insert(8, "overfitting_balanced", 0, True)

# %%
for i in range(len(metricas_balanceo)):
    metricas_balanceo['overfitting_balanced'][i]= (np.abs((metricas_balanceo["balanced_accucracy"][i] - metricas_balanceo["acc_train"][i]) / metricas_balanceo["balanced_accucracy"][i])*100 )
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
metricas_balanceo.head(1)
# Out:
#    index gridSearch  accu_std  accu_mod  acc_test  acc_train  overfitting %  \
# 0      0        SVC  0.793173  0.946674  0.886546   0.977693      10.281081
#
#      recall  overfitting_balanced       f1  precission  balanced_accucracy  \
# 0  0.058824                    97  0.05042    0.044118             0.49502
#
#        ROC balance_method
# 0  0.49502            ros

# %%
metricas_balanceo.groupby(['balance_method', 'gridSearch'])['recall'].aggregate('mean').unstack()
# Out:
# gridSearch         AdaBoost  CatBoost  DecissionTree  GradientBoosting  \
# balance_method
# condensed_nearest  0.000000  0.019608       0.000000          0.000000
# near_miss          0.627451  0.666667       0.607843          0.843137
# ros                0.803922  0.509804       0.666667          0.019608
# rus                0.882353  0.882353       0.882353          0.862745
# smote              0.450980  0.333333       0.686275          0.039216
#
# gridSearch              KNN      LGBM  LogisticRegression  RandomForest  \
# balance_method
# condensed_nearest  0.039216  0.000000            0.078431      0.039216
# near_miss          0.666667  0.725490            0.725490      0.823529
# ros                0.078431  0.705882            0.843137      0.039216
# rus                0.647059  0.882353            0.862745      0.803922
# smote              0.078431  0.000000            0.725490      0.098039
#
# gridSearch              SVC       XGB
# balance_method
# condensed_nearest  0.000000  0.000000
# near_miss          0.823529  0.705882
# ros                0.058824  0.019608
# rus                0.862745  0.882353
# smote              0.078431  0.078431

# %%
metricas_balanceo.pivot_table(index='balance_method', columns='gridSearch',
                    aggfunc={'acc_test':'mean', 'recall':'mean'})
# Out:
#                    acc_test                                           \
# gridSearch         AdaBoost  CatBoost DecissionTree GradientBoosting
# balance_method
# condensed_nearest  0.948795  0.944779      0.948795         0.948795
# near_miss          0.554217  0.349398      0.390562         0.251004
# ros                0.765060  0.857430      0.732932         0.943775
# rus                0.695783  0.679719      0.695783         0.696787
# smote              0.865462  0.876506      0.830321         0.931727
#
#                                                                        \
# gridSearch              KNN      LGBM LogisticRegression RandomForest
# balance_method
# condensed_nearest  0.949799  0.948795           0.939759     0.932731
# near_miss          0.290161  0.439759           0.374498     0.248996
# ros                0.916667  0.772088           0.770080     0.941767
# rus                0.610442  0.709839           0.738956     0.705823
# smote              0.885542  0.948795           0.832329     0.914659
#
#                                          recall                          \
# gridSearch              SVC       XGB  AdaBoost  CatBoost DecissionTree
# balance_method
# condensed_nearest  0.948795  0.948795  0.000000  0.019608      0.000000
# near_miss          0.255020  0.383534  0.627451  0.666667      0.607843
# ros                0.886546  0.925703  0.803922  0.509804      0.666667
# rus                0.734940  0.708835  0.882353  0.882353      0.882353
# smote              0.900602  0.932731  0.450980  0.333333      0.686275
#
#                                                                            \
# gridSearch        GradientBoosting       KNN      LGBM LogisticRegression
# balance_method
# condensed_nearest         0.000000  0.039216  0.000000           0.078431
# near_miss                 0.843137  0.666667  0.725490           0.725490
# ros                       0.019608  0.078431  0.705882           0.843137
# rus                       0.862745  0.647059  0.882353           0.862745
# smote                     0.039216  0.078431  0.000000           0.725490
#
#
# gridSearch        RandomForest       SVC       XGB
# balance_method
# condensed_nearest     0.039216  0.000000  0.000000
# near_miss             0.823529  0.823529  0.705882
# ros                   0.039216  0.058824  0.019608
# rus                   0.803922  0.862745  0.882353
# smote                 0.098039  0.078431  0.078431

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

metricas_balanceo.pivot_table('recall', index='balance_method',
                    columns='gridSearch', aggfunc='mean').plot(figsize=(10,6))

plt.tick_params(axis="x", length=6, width=2, colors='r', labelrotation=45.0)
plt.tick_params(axis="y", length=3, width=4, colors='b')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.ylabel('recall')

plt.show()
#plt.gca().set_xticklabels(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'])
#plt.ylabel('mean births by day');

# %%
metricas_balanceo.pivot_table('acc_test', index='balance_method',
                    columns='gridSearch', aggfunc='mean').plot(figsize=(10,6))
                                                               
plt.tick_params(axis="x", length=6, width=2, colors='r', labelrotation=45.0)
plt.tick_params(axis="y", length=3, width=4, colors='b')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.ylabel('accuracy (test)')
                                                               
plt.show()

# %%
metricas_balanceo.pivot_table('balanced_accucracy', index='balance_method',
                    columns='gridSearch', aggfunc='mean').plot(figsize=(10,6))
                                                               
plt.tick_params(axis="x", length=6, width=2, colors='r', labelrotation=45.0)
plt.tick_params(axis="y", length=3, width=4, colors='b')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()
plt.ylabel('Balanced_accuracy (test)')
                                                               
plt.show()

# %%
metricas_balanceo.pivot_table('overfitting_balanced', index='balance_method',
                    columns='gridSearch', aggfunc='mean').plot(figsize=(10,6))

plt.tick_params(axis="x", length=6, width=2, colors='r', labelrotation=45.0)
plt.tick_params(axis="y", length=3, width=4, colors='b')
plt.ylabel('overfitting balanceado (%)')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()

plt.show()

# %%
metricas_balanceo.pivot_table('f1', index='balance_method',
                    columns='gridSearch', aggfunc='mean').plot(figsize=(10,6))

plt.tick_params(axis="x", length=6, width=2, colors='r', labelrotation=45.0)
plt.tick_params(axis="y", length=3, width=4, colors='b')
plt.ylabel('f1')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()

plt.show()

# %%
metricas_balanceo.pivot_table('ROC', index='balance_method',
                    columns='gridSearch', aggfunc='mean').plot(figsize=(10,6))

plt.tick_params(axis="x", length=6, width=2, colors='r', labelrotation=45.0)
plt.tick_params(axis="y", length=3, width=4, colors='b')
plt.ylabel('ROC_AUC')
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.tight_layout()

plt.show()

# %%
fig = px.scatter_3d(metricas_balanceo, x='balanced_accucracy', y='overfitting_balanced', z='recall',
              color='gridSearch', color_continuous_scale='bluered', opacity=0.5 , size_max=18,)

# tight layout

fig.update_layout(margin=dict(l=0, r=0, b=0, t=0) , 
                 scene = dict(
                    xaxis_title='Balance Accuracy',
                    yaxis_title='Overfitting %',
                    zaxis_title='Recall'), 
                 width=900)


fig.show()
# Out:
# <div>                            <div id="c6465578-5d8b-4082-94ab-5b79b265e0a4" class="plotly-graph-div" style="height:525px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6465578-5d8b-4082-94ab-5b79b265e0a4")) {                    Plotly.newPlot(                        "c6465578-5d8b-4082-94ab-5b79b265e0a4",                        [{"hovertemplate":"gridSearch=SVC<br>balanced_accucracy=%{x}<br>overfitting_balanced=%{y}<br>recall=%{z}<extra></extra>","legendgroup":"SVC","marker":{"color":"#636efa","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"SVC","scene":"scene","showlegend":true,"x":[0.4950202303143479,0.7953937130407719,0.5117024587612823,0.5,0.5239340180516651],"y":[97,2,89,46,66],"z":[0.0588235294117647,0.8627450980392157,0.0784313725490196,0.0,0.8235294117647058],"type":"scatter3d"},{"hovertemplate":"gridSearch=LogisticRegression<br>balanced_accucracy=%{x}<br>overfitting_balanced=%{y}<br>recall=%{z}<extra></extra>","legendgroup":"LogisticRegression","marker":{"color":"#EF553B","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"LogisticRegression","scene":"scene","showlegend":true,"x":[0.8046374105197635,0.797510115157174,0.7817927170868347,0.532337379396203,0.5405228758169934],"y":[3,0,0,38,53],"z":[0.8431372549019608,0.8627450980392157,0.7254901960784313,0.0784313725490196,0.7254901960784313],"type":"scatter3d"},{"hovertemplate":"gridSearch=DecissionTree<br>balanced_accucracy=%{x}<br>overfitting_balanced=%{y}<br>recall=%{z}<extra></extra>","legendgroup":"DecissionTree","marker":{"color":"#00cc96","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"DecissionTree","scene":"scene","showlegend":true,"x":[0.7015873015873015,0.7840336134453781,0.7621848739495798,0.5,0.4933395580454404],"y":[14,1,7,46,75],"z":[0.6666666666666666,0.8823529411764706,0.6862745098039216,0.0,0.6078431372549019],"type":"scatter3d"},{"hovertemplate":"gridSearch=KNN<br>balanced_accucracy=%{x}<br>overfitting_balanced=%{y}<br>recall=%{z}<extra></extra>","legendgroup":"KNN","marker":{"color":"#ab63fa","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"KNN","scene":"scene","showlegend":true,"x":[0.5201680672268908,0.6277622159975101,0.5037659508247744,0.5190787426081543,0.4682539682539682],"y":[92,13,98,43,89],"z":[0.0784313725490196,0.6470588235294118,0.0784313725490196,0.0392156862745098,0.6666666666666666],"type":"scatter3d"},{"hovertemplate":"gridSearch=GradientBoosting<br>balanced_accucracy=%{x}<br>overfitting_balanced=%{y}<br>recall=%{z}<extra></extra>","legendgroup":"GradientBoosting","marker":{"color":"#FFA15A","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"GradientBoosting","scene":"scene","showlegend":true,"x":[0.5066293183940243,0.7752878929349518,0.5095549330843449,0.5,0.5310924369747899],"y":[97,3,96,46,87],"z":[0.0196078431372549,0.8627450980392157,0.0392156862745098,0.0,0.8431372549019608],"type":"scatter3d"},{"hovertemplate":"gridSearch=RandomForest<br>balanced_accucracy=%{x}<br>overfitting_balanced=%{y}<br>recall=%{z}<extra></extra>","legendgroup":"RandomForest","marker":{"color":"#19d3f3","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"RandomForest","scene":"scene","showlegend":true,"x":[0.5148459383753502,0.7522253345782758,0.5283846872082166,0.5100840336134453,0.5207594148770619],"y":[94,32,89,96,92],"z":[0.0392156862745098,0.803921568627451,0.0980392156862745,0.0392156862745098,0.8235294117647058],"type":"scatter3d"},{"hovertemplate":"gridSearch=AdaBoost<br>balanced_accucracy=%{x}<br>overfitting_balanced=%{y}<br>recall=%{z}<extra></extra>","legendgroup":"AdaBoost","marker":{"color":"#FF6692","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"AdaBoost","scene":"scene","showlegend":true,"x":[0.7834422657952069,0.7840336134453781,0.6694055399937753,0.5,0.5888577653283535],"y":[4,1,27,4 ...

# %%
metricas_balanceo.describe()
# Out:
#            index   accu_std   accu_mod   acc_test  acc_train  overfitting %  \
# count  50.000000  50.000000  50.000000  50.000000  50.000000      50.000000
# mean    4.500000   0.739518   0.817665   0.748092   0.854554      44.816992
# std     2.901442   0.228562   0.085373   0.224071   0.104039      73.997299
# min     0.000000   0.227912   0.625083   0.248996   0.625083       1.026228
# 25%     2.000000   0.693022   0.753634   0.695783   0.782359       8.084740
# 50%     4.500000   0.835341   0.796154   0.831325   0.824664      13.872794
# 75%     7.000000   0.919428   0.853846   0.932731   0.975638      22.673145
# max     9.000000   0.948795   0.994456   0.949799   1.000000     301.612903
#
#           recall  overfitting_balanced         f1  precission  \
# count  50.000000             50.000000  50.000000   50.000000
# mean    0.443137             47.100000   0.131043    0.110387
# std     0.366037             35.376257   0.095061    0.101517
# min     0.000000              0.000000   0.000000    0.000000
# 25%     0.039216             13.250000   0.058383    0.053881
# 50%     0.617647             46.000000   0.105110    0.106818
# 75%     0.803922             87.750000   0.228166    0.147656
# max     0.882353            101.000000   0.307054    0.666667
#
#        balanced_accucracy        ROC
# count           50.000000  50.000000
# mean             0.603844   0.603844
# std              0.121464   0.121464
# min              0.468254   0.468254
# 25%              0.504482   0.504482
# 50%              0.529863   0.529863
# 75%              0.749362   0.749362
# max              0.804637   0.804637

# %% [markdown]
# # Mejores modelos de balanceo y algoritmos para Ictus DataSet --Equipo Cerebro

# %%
best_models_ever = metricas_balanceo[(metricas_balanceo['balanced_accucracy']>0.7)
                                     & (metricas_balanceo['recall']>0.6) & (metricas_balanceo['overfitting_balanced']<=5)].sort_values('recall', ascending = False) 
                                                                                
best_models_ever
# Out:
#     index          gridSearch  accu_std  accu_mod  acc_test  acc_train  \
# 12      2       DecissionTree  0.683735  0.782051  0.695783   0.792308
# 16      6            AdaBoost  0.712851  0.784615  0.695783   0.792308
# 17      7                 XGB  0.709839  0.797436  0.708835   0.802564
# 18      8            CatBoost  0.717871  0.792308  0.679719   0.800000
# 19      9                LGBM  0.708835  0.746154  0.709839   0.792308
# 10      0                 SVC  0.658635  0.794872  0.734940   0.817949
# 11      1  LogisticRegression  0.730924  0.779487  0.738956   0.800000
# 14      4    GradientBoosting  0.726908  0.794872  0.696787   0.802564
# 1       1  LogisticRegression  0.770080  0.777851  0.770080   0.777983
# 6       6            AdaBoost  0.770080  0.813622  0.765060   0.817582
# 21      1  LogisticRegression  0.831325  0.776073  0.832329   0.779043
#
#     overfitting %    recall  overfitting_balanced        f1  precission  \
# 12      13.872794  0.882353                     1  0.229008    0.131579
# 16      13.872794  0.882353                     1  0.229008    0.131579
# 17      13.222924  0.882353                     1  0.236842    0.136778
# 18      17.695716  0.882353                     3  0.220049    0.125698
# 19      11.617887  0.882353                     0  0.237467    0.137195
# 10      11.294662  0.862745                     2  0.250000    0.146179
# 11       8.260870  0.862745                     0  0.252874    0.148148
# 14      15.180669  0.862745                     3  0.225641    0.129794
# 1        1.026228  0.843137                     3  0.273016    0.162879
# 6        6.865028  0.803922                     4  0.259494    0.154717
# 21       6.402083  0.725490                     0  0.307054    0.194737
#
#     balanced_accucracy       ROC balance_method
# 12            0.784034  0.784034            rus
# 16            0.784034  0.784034            rus
# 17            0.790912  0.790912            rus
# 18            0.775568  0.775568            rus
# 19            0.791441  0.791441            rus
# 10            0.795394  0.795394            rus
# 11            0.797510  0.797510            rus
# 14            0.775288  0.775288            rus
# 1             0.804637  0.804637            ros
# 6             0.783442  0.783442            ros
# 21            0.781793  0.781793          smote

# %% [markdown]
# # Implementacion libreria H20

# %%
import h2o
from h2o.estimators.gbm import H2OGradientBoostingEstimator
from h2o.grid.grid_search import H2OGridSearch
from h2o.estimators.estimator_base import H2OEstimator
h2o.init()
h2o.cluster().show_status()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.16" 2022-07-19; OpenJDK Runtime Environment (build 11.0.16+8-post-Ubuntu-0ubuntu120.04); OpenJDK 64-Bit Server VM (build 11.0.16+8-post-Ubuntu-0ubuntu120.04, mixed mode, sharing)
#   Starting server from /opt/conda/lib/python3.7/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp6j4cvtse
#   JVM stdout: /tmp/tmp6j4cvtse/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmp6j4cvtse/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.4
# H2O_cluster_version_age:    1 month and 23 days
# H2O_cluster_name:           H2O_from_python_unknownUser_i89f66
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    4 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.12 final
# --------------------------  ----------------------------------
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.4
# H2O_cluster_version_age:    1 month and 23 days
# H2O_cluster_name:           H2O_from_python_unknownUser_i89f66
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    4 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.12 final
# --------------------------  ----------------------------------

# %%
df= pd.read_csv('/kaggle/input/ictus-data-set/stroke_dataset.csv')
ictus_frame = h2o.H2OFrame(df)
ictus_frame
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# <tr><th>gender  </th><th style="text-align: right;">  age</th><th style="text-align: right;">  hypertension</th><th style="text-align: right;">  heart_disease</th><th>ever_married  </th><th>work_type    </th><th>Residence_type  </th><th style="text-align: right;">  avg_glucose_level</th><th style="text-align: right;">  bmi</th><th>smoking_status  </th><th style="text-align: right;">  stroke</th></tr>
# </thead>
# <tbody>
# <tr><td>Male    </td><td style="text-align: right;">   67</td><td style="text-align: right;">             0</td><td style="text-align: right;">              1</td><td>Yes           </td><td>Private      </td><td>Urban           </td><td style="text-align: right;">             228.69</td><td style="text-align: right;"> 36.6</td><td>formerly smoked </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Male    </td><td style="text-align: right;">   80</td><td style="text-align: right;">             0</td><td style="text-align: right;">              1</td><td>Yes           </td><td>Private      </td><td>Rural           </td><td style="text-align: right;">             105.92</td><td style="text-align: right;"> 32.5</td><td>never smoked    </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Female  </td><td style="text-align: right;">   49</td><td style="text-align: right;">             0</td><td style="text-align: right;">              0</td><td>Yes           </td><td>Private      </td><td>Urban           </td><td style="text-align: right;">             171.23</td><td style="text-align: right;"> 34.4</td><td>smokes          </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Female  </td><td style="text-align: right;">   79</td><td style="text-align: right;">             1</td><td style="text-align: right;">              0</td><td>Yes           </td><td>Self-employed</td><td>Rural           </td><td style="text-align: right;">             174.12</td><td style="text-align: right;"> 24  </td><td>never smoked    </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Male    </td><td style="text-align: right;">   81</td><td style="text-align: right;">             0</td><td style="text-align: right;">              0</td><td>Yes           </td><td>Private      </td><td>Urban           </td><td style="text-align: right;">             186.21</td><td style="text-align: right;"> 29  </td><td>formerly smoked </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Male    </td><td style="text-align: right;">   74</td><td style="text-align: right;">             1</td><td style="text-align: right;">              1</td><td>Yes           </td><td>Private      </td><td>Rural           </td><td style="text-align: right;">              70.09</td><td style="text-align: right;"> 27.4</td><td>never smoked    </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Female  </td><td style="text-align: right;">   69</td><td style="text-align: right;">             0</td><td style="text-align: right;">              0</td><td>No            </td><td>Private      </td><td>Urban           </td><td style="text-align: right;">              94.39</td><td style="text-align: right;"> 22.8</td><td>never smoked    </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Female  </td><td style="text-align: right;">   78</td><td style="text-align: right;">             0</td><td style="text-align: right;">              0</td><td>Yes           </td><td>Private      </td><td>Urban           </td><td style="text-align: right;">              58.57</td><td style="text-align: right;"> 24.2</td><td>Unknown         </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Female  </td><td style="text-align: right;">   81</td><td style="text-align: right;">             1</td><td style="text-align: right;">              0</td><td>Yes           </td><td>Private      </td><td>Rural           </td><td style="text-align: right;">              80.43</td><td style="text-align: right;"> 29.7</td><td>never smoked    </td><td style="text-align: right;">       1</td></tr>
# <tr><td>Female  </td><td style="text-align: right;">   61</td><td style="text-align: right;">             0</td><td style="text-align: right;">              1</td><td>Yes           </td><td>Govt_job     </td><td>Rural           </td><td style="text-align: right;">             120.46</td><td style="text-align: right;"> 36.8</td><td>smokes          </td><td style="text-align: right;">       1</td></tr>
# </tbody>
# </table>

# %%
# convert response column to a factor
ictus_frame[10] = ictus_frame[10].asfactor()

# set the predictor names and the response column name
predictors = ictus_frame.columns[0:10]
response= 'stroke'

# split into train and validation sets
train, valid = ictus_frame.split_frame(ratios = [.8], seed = 1234)

# %% [markdown]
# # Búsqueda de hiperparámetros

# %%
# Hiperparámetros que se quieren comparar.

hiperparametros = {
                   "learn_rate":[0.001, 0.05, 0.1],
                   "max_depth":[5, 10, 15, 20],
                   "sample_rate":[0.8, 1] 
                  }

gbm_grid = H2OGridSearch(
                model=H2OGradientBoostingEstimator(
                        distribution = "bernoulli",
                        # Número de árboles.
                        ntrees = 5000,
                        # Preprocesado.
                        ignore_const_cols = True,
                        # Validación cruzada de 10 folds para estimar el error
                        # del modelo.
                        seed = 123,
                        nfolds = 10,
                        # Reparto estratificado de las observaciones en la creación
                        # de las particiones.
                        fold_assignment = "Stratified",
                        keep_cross_validation_predictions = False,
                        # Detención temprana
                        score_tree_interval = 5,
                        stopping_rounds = 3,
                        stopping_metric = "aucpr",
                        stopping_tolerance = 0.001,
                        balance_classes = True ,
                       ),
                hyper_params    = hiperparametros,
                search_criteria = {'strategy': "Cartesian"},
                grid_id         = 'gbm_grid'
              )

gbm_grid.train(
    y = response,
    x = predictors,
    training_frame = train,
)



# Resultados grid search
# ------------------------------------------------------------------------------
gbm_grid.get_grid(sort_by="aucpr", decreasing=True).sorted_metric_table()
# Out:
# gbm Grid Build progress: |███████████████████████████████████████████████████████| (done) 100%
#       learn_rate  max_depth  sample_rate          model_ids     aucpr
# 0          0.050        5.0          1.0  gbm_grid_model_14  0.174224
# 1          0.050        5.0          0.8   gbm_grid_model_2  0.173089
# 2          0.100        5.0          0.8   gbm_grid_model_3  0.167668
# 3          0.100        5.0          1.0  gbm_grid_model_15  0.162273
# 4          0.100       10.0          0.8   gbm_grid_model_6  0.148055
# 5          0.050       10.0          0.8   gbm_grid_model_5  0.144707
# 6          0.050       15.0          0.8   gbm_grid_model_8  0.130482
# 7          0.100       20.0          0.8  gbm_grid_model_12  0.129390
# 8          0.050       20.0          0.8  gbm_grid_model_11  0.127042
# 9          0.050       10.0          1.0  gbm_grid_model_17  0.125271
# 10         0.100       10.0          1.0  gbm_grid_model_18  0.124383
# 11         0.100       15.0          1.0  gbm_grid_model_21  0.121725
# 12         0.100       15.0          0.8   gbm_grid_model_9  0.117896
# 13         0.001        5.0          1.0  gbm_grid_model_13  0.117228
# 14         0.100       20.0          1.0  gbm_grid_model_24  0.116319
# 15         0.001        5.0          0.8   gbm_grid_model_1  0.114711
# 16         0.050       15.0          1.0  gbm_grid_model_20  0.112412
# 17         0.001       10.0          0.8   gbm_grid_model_4  0.108112
# 18         0.050       20.0          1.0  gbm_grid_model_23  0.107109
# 19         0.001       15.0          0.8   gbm_grid_model_7  0.103415
# 20         0.001       20.0          0.8  gbm_grid_model_10  0.102791
# 21         0.001       20.0          1.0  gbm_grid_model_22  0.082357
# 22         0.001       10.0          1.0  gbm_grid_model_16  0.082171
# 23         0.001       15.0          1.0  gbm_grid_model_19  0.078460

# %%
# Mejor modelo
# ------------------------------------------------------------------------------
id_mejor_modelo = gbm_grid.get_grid(sort_by="aucpr", decreasing=True)\
                  .sorted_metric_table()['model_ids'][0]

mejor_gbm_final = h2o.get_model(id_mejor_modelo)

# %%
# retrieve the model performance
perf = mejor_gbm_final.model_performance(valid)
perf
# Out:
# ModelMetricsBinomial: gbm
# ** Reported on test data. **
#
# MSE: 0.04754542036842939
# RMSE: 0.21804912375065713
# LogLoss: 0.17778959392543897
# Mean Per-Class Error: 0.3322377764252384
# AUC: 0.8321870561980118
# AUCPR: 0.21829180715273586
# Gini: 0.6643741123960236
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.10612126779366014:
#               0     1   Error            Rate
# 0      0  856.0  74.0  0.0796    (74.0/930.0)
# 1      1   31.0  22.0  0.5849     (31.0/53.0)
# 2  Total  887.0  96.0  0.1068   (105.0/983.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold       value    idx
# 0                        max f1   0.106121    0.295302   80.0
# 1                        max f2   0.029761    0.445736  223.0
# 2                  max f0point5   0.178623    0.275229   12.0
# 3                  max accuracy   0.220707    0.947101    0.0
# 4                 max precision   0.220707    1.000000    0.0
# 5                    max recall   0.004168    1.000000  385.0
# 6               max specificity   0.220707    1.000000    0.0
# 7              max absolute_mcc   0.029761    0.288557  223.0
# 8    max min_per_class_accuracy   0.040020    0.762366  195.0
# 9   max mean_per_class_accuracy   0.029761    0.795253  223.0
# 10                      max tns   0.220707  930.000000    0.0
# 11                      max fns   0.220707   52.000000    0.0
# 12                      max fps   0.003352  930.000000  399.0
# 13                      max tps   0.004168   53.000000  385.0
# 14                      max tnr   0.220707    1.000000    0.0
# 15                      max fnr   0.220707    0.981132    0.0
# 16                      max fpr   0.003352    1.000000  399.0
# 17                      max tpr   0.004168    1.000000  385.0
# Gains/Lift Table: Avg response rate:  5.39 %, avg score:  3.21 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010173         0.187437  7.418868
# 1       2                  0.020346         0.171889  3.709434
# 2       3                  0.030519         0.161515  1.854717
# 3       4                  0.040692         0.149546  7.418868
# 4       5                  0.050865         0.140340  3.709434
# 5       6                  0.101729         0.102997  3.338491
# 6       7                  0.150560         0.065498  1.545597
# 7       8                  0.200407         0.053877  2.649596
# 8       9                  0.300102         0.030936  2.081825
# 9      10                  0.399797         0.017689  0.567771
# 10     11                  0.500509         0.009320  0.374690
# 11     12                  0.600203         0.005424  0.567771
# 12     13                  0.702950         0.004501  0.000000
# 13     14                  0.803662         0.004306  0.000000
# 14     15                  0.899288         0.003995  0.197310
# 15     16                  1.000000         0.003309  0.000000
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          7.418868       0.400000  0.196913                  0.400000
# 1          5.564151       0.200000  0.177801                  0.300000
# 2          4.327673       0.100000  0.167105                  0.233333
# 3          5.100472       0.400000  0.153705                  0.275000
# 4          4.822264       0.200000  0.143273                  0.260000
# 5          4.080377       0.180000  0.121522                  0.220000
# 6          3.258287       0.083333  0.081895                  0.175676
# 7          3.106886       0.142857  0.058800                  0.167513
# 8          2.766358       0.112245  0.043508                  0.149153
# 9          2.218109       0.030612  0.023768                  0.119593
# 10         1.847177       0.020202  0.012918                  0.099593
# 11         1.634666       0.030612  0.007040                  0.088136
# 12         1.395735       0.000000  0.004871                  0.075253
# 13         1.220826       0.000000  0.004360                  0.065823
# 14         1.111991       0.010638  0.004160                  0.059955
# 15         1.000000       0.000000  0.003745                  0.053917
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.196913      0.075472                 0.075472  641.886792
# 1           0.187357      0.037736                 0.113208  270.943396
# 2           0.180606      0.018868                 0.132075   85.471698
# 3           0.173881      0.075472                 0.207547  641.886792
# 4           0.167759      0.037736                 0.245283  270.943396
# 5           0.144641      0.169811                 0.415094  233.849057
# 6           0.124291      0.075472                 0.490566   54.559748
# 7           0.108001      0.132075                 0.622642  164.959569
# 8           0.086576      0.207547                 0.830189  108.182518
# 9           0.070914      0.056604                 0.886792  -43.222950
# 10          0.059244      0.037736                 0.924528  -62.530970
# 11          0.050573      0.056604                 0.981132  -43.222950
# 12          0.043893      0.000000                 0.981132 -100.000000
# 13          0.038939      0.000000                 0.981132 -100.000000
# 14          0.035241      0.018868                 1.000000  -80.268968
# 15          0.032069      0.000000                 1.000000 -100.000000
#
#     cumulative_gain  kolmogorov_smirnov
# 0        641.886792            0.069020
# 1        456.415094            0.098154
# 2        332.767296            0.107344
# 3        410.047170            0.176364
# 4        382.226415            0.205498
# 5        308.037736            0.331223
# 6        225.828659            0.359383
# 7        210.688631            0.446297
# 8        176.635753            0.560296
# 9        121.810937            0.514749
# 10        84.717748            0.448184
# 11        63.466581            0.402637
# 12        39.573492            0.294035
# 13        22.082637            0.187584
# 14        11.199095            0.106452
# 15         0.000000            0.000000

# %%
# Cálculo de la métrica AUC para el conjunto de test.
performance = mejor_gbm_final.model_performance(valid)
performance.accuracy()
# Out:
# [[0.22070734964333488, 0.9471007121057986]]

# %%
performance_train = mejor_gbm_final.model_performance(test_data = train)
performance.accuracy()
# Out:
# [[0.22070734964333488, 0.9471007121057986]]

# %%
perf.accuracy()
# Out:
# [[0.22070734964333488, 0.9471007121057986]]

# %%
h2o.shutdown()
# Out:
# H2O session _sid_8ca0 closed.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: H2ODeprecationWarning: Deprecated, use ``h2o.cluster().shutdown()``.
#   """Entry point for launching an IPython kernel.

# %%
# EJEMPLO DE GRID CON POCOS PARAMETROS
# try using the balance_classes parameter (set to True):

cov_gbm.train(x = predictors, y = response, training_frame = train, validation_frame = valid)

print('accuracy', cov_gbm.logloss(valid = True))

# select the values for `balance_classes` to grid over
hyper_params = {'balance_classes': [True, False]}

# this example uses cartesian grid search because the search space is small
# and we want to see the performance of all models. For a larger search space use
# random grid search instead: {'strategy': "RandomDiscrete"}
# initialize the GBM estimator
cov_gbm_2 = H2OGradientBoostingEstimator(seed = 1234)

# build grid search with previously made GBM and hyperparameters
grid = H2OGridSearch(model = cov_gbm_2, hyper_params = hyper_params,
                     search_criteria = {'strategy': "RandomDiscrete"})

# train using the grid
grid.train(x = predictors, y = response, training_frame = train, validation_frame = valid)

# sort the grid models by logloss
sorted_grid = grid.get_grid(sort_by='accuracy', decreasing=False)
print(sorted_grid)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         52 mins 50 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.4
# H2O_cluster_version_age:    1 month and 23 days
# H2O_cluster_name:           H2O_from_python_unknownUser_r7oifk
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.077 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.12 final
# --------------------------  ----------------------------------
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         52 mins 50 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.4
# H2O_cluster_version_age:    1 month and 23 days
# H2O_cluster_name:           H2O_from_python_unknownUser_r7oifk
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.077 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.12 final
# --------------------------  ----------------------------------
# gbm Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# accuracy 0.19620885300401106
# gbm Grid Build progress: |███████████████████████████████████████████████████████| (done) 100%
#     balance_classes  \
# 0              true
# 1             false
#
#                                                           model_ids  accuracy
# 0  Grid_GBM_py_14_sid_a673_model_python_1664277417931_13044_model_1  0.946083
# 1  Grid_GBM_py_14_sid_a673_model_python_1664277417931_13044_model_2  0.946083

# %%
# Mejor modelo
# ------------------------------------------------------------------------------
gbm_mejor_modelo = grid.get_grid(sort_by="accuracy", decreasing=True)\
                  .sorted_metric_table()['model_ids'][0]

gbm_final = h2o.get_model(gbm_mejor_modelo)

# %%
perf_gbm.aucpr()
# Out:
# 0.18954197469136266

# %%
# retrieve the model performance
perf_gbm= gbm_final.model_performance(valid)
perf_gbm
# Out:
# ModelMetricsBinomial: gbm
# ** Reported on test data. **
#
# MSE: 0.04836179464758599
# RMSE: 0.21991315251159033
# LogLoss: 0.19620885300401106
# Mean Per-Class Error: 0.31038750253601133
# AUC: 0.8184114424832624
# AUCPR: 0.18954197469136266
# Gini: 0.6368228849665247
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.06841871241832227:
#               0      1   Error            Rate
# 0      0  844.0   86.0  0.0925    (86.0/930.0)
# 1      1   28.0   25.0  0.5283     (28.0/53.0)
# 2  Total  872.0  111.0   0.116   (114.0/983.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold       value    idx
# 0                        max f1   0.068419    0.304878  107.0
# 1                        max f2   0.041840    0.418848  156.0
# 2                  max f0point5   0.181468    0.268456   23.0
# 3                  max accuracy   0.308395    0.946083    1.0
# 4                 max precision   0.308395    0.500000    1.0
# 5                    max recall   0.001175    1.000000  377.0
# 6               max specificity   0.338751    0.998925    0.0
# 7              max absolute_mcc   0.053334    0.279541  129.0
# 8    max min_per_class_accuracy   0.018060    0.730108  246.0
# 9   max mean_per_class_accuracy   0.005517    0.747210  328.0
# 10                      max tns   0.338751  929.000000    0.0
# 11                      max fns   0.338751   53.000000    0.0
# 12                      max fps   0.000404  930.000000  399.0
# 13                      max tps   0.001175   53.000000  377.0
# 14                      max tnr   0.338751    0.998925    0.0
# 15                      max fnr   0.338751    1.000000    0.0
# 16                      max fpr   0.000404    1.000000  399.0
# 17                      max tpr   0.001175    1.000000  377.0
# Gains/Lift Table: Avg response rate:  5.39 %, avg score:  2.44 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010173         0.216952  5.564151
# 1       2                  0.020346         0.185418  3.709434
# 2       3                  0.030519         0.163096  5.564151
# 3       4                  0.040692         0.147569  3.709434
# 4       5                  0.050865         0.129201  0.000000
# 5       6                  0.100712         0.074575  3.785137
# 6       7                  0.150560         0.047359  3.406623
# 7       8                  0.200407         0.035238  1.514055
# 8       9                  0.300102         0.017324  1.135541
# 9      10                  0.399797         0.008629  0.946284
# 10     11                  0.500509         0.003810  0.936726
# 11     12                  0.600203         0.001716  0.567771
# 12     13                  0.699898         0.001010  0.189257
# 13     14                  0.799593         0.000873  0.000000
# 14     15                  0.899288         0.000760  0.000000
# 15     16                  1.000000         0.000395  0.000000
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          5.564151       0.300000  0.264507                  0.300000
# 1          4.636792       0.200000  0.205288                  0.250000
# 2          4.945912       0.300000  0.177348                  0.266667
# 3          4.636792       0.200000  0.155819                  0.250000
# 4          3.709434       0.000000  0.137416                  0.200000
# 5          3.746903       0.204082  0.098427                  0.202020
# 6          3.634243       0.183673  0.060523                  0.195946
# 7          3.106886       0.081633  0.040923                  0.167513
# 8          2.451999       0.061224  0.024446                  0.132203
# 9          2.076528       0.051020  0.012508                  0.111959
# 10         1.847177       0.050505  0.005844                  0.099593
# 11         1.634666       0.030612  0.002576                  0.088136
# 12         1.428779       0.010204  0.001247                  0.077035
# 13         1.250636       0.000000  0.000945                  0.067430
# 14         1.111991       0.000000  0.000818                  0.059955
# 15         1.000000       0.000000  0.000644                  0.053917
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.264507      0.056604                 0.056604  456.415094
# 1           0.234897      0.037736                 0.094340  270.943396
# 2           0.215714      0.056604                 0.150943  456.415094
# 3           0.200740      0.037736                 0.188679  270.943396
# 4           0.188076      0.000000                 0.188679 -100.000000
# 5           0.143704      0.188679                 0.377358  278.513670
# 6           0.116164      0.169811                 0.547170  240.662303
# 7           0.097450      0.075472                 0.622642   51.405468
# 8           0.073198      0.113208                 0.735849   13.554101
# 9           0.058064      0.094340                 0.830189   -5.371583
# 10          0.047556      0.094340                 0.924528   -6.327425
# 11          0.040085      0.056604                 0.981132  -43.222950
# 12          0.034553      0.018868                 1.000000  -81.074317
# 13          0.030362      0.000000                 1.000000 -100.000000
# 14          0.027087      0.000000                 1.000000 -100.000000
# 15          0.024424      0.000000                 1.000000 -100.000000
#
#     cumulative_gain  kolmogorov_smirnov
# 0        456.415094            0.049077
# 1        363.679245            0.078211
# 2        394.591195            0.127287
# 3        363.679245            0.156421
# 4        270.943396            0.145668
# 5        274.690299            0.292412
# 6        263.424273            0.419213
# 7        210.688631            0.446297
# 8        145.199872            0.460580
# 9        107.652792            0.454920
# 10        84.717748            0.448184
# 11        63.466581            0.402637
# 12        42.877907            0.317204
# 13        25.063613            0.211828
# 14        11.199095            0.106452
# 15         0.000000            0.000000

# %%
# retrieve the model performance
perf = airlines_gbm.model_performance(valid)
perf

# %%
ictus_gbm = H2OGradientBoostingEstimator(sample_rate = .7, seed = 1234)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib 
plt.style.use("ggplot")
import plotly.express as px
from matplotlib import rcParams
rcParams['figure.figsize'] = 14, 7
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False

# %%
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier

## Optimización de hiperparámetros
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid
import multiprocessing
from multiprocessing import Pool
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import KFold
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
## Métricas de evaluación
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer

# %%
df= pd.read_csv('/kaggle/input/ictus-data-set/stroke_dataset.csv')

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder , LabelEncoder
from sklearn.compose import ColumnTransformer

numericas = ["age", "avg_glucose_level" , "bmi" , "hypertension", "heart_disease"]
categoricas= ["work_type" , "smoking_status" , "gender", "ever_married" , "Residence_type"]

#Configuro los transformer
transformer_numerico = ("transformer_numerico",MinMaxScaler(), numericas) 
transformer_categorico = ("transformer_categorico",OneHotEncoder(), categoricas)

#Defino el transformer
transformer = ColumnTransformer ([transformer_numerico, transformer_categorico ], remainder="passthrough")

# %%
X = df.drop('stroke',axis=1)
y= df['stroke']
X_ub = transformer.fit_transform(X) 

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_ub, y, test_size=0.20, random_state=101, stratify=y)

# %%
from imblearn.over_sampling import RandomOverSampler
os =  RandomOverSampler(random_state=0)

X_train_os, y_train_os = os.fit_resample(X_train,y_train)

# %%
# Grid de hiperparámetros evaluados
# ==============================================================================
param_grid = {'learning_rate' : [0.1],
              'n_estimators'  : [500],
             #'num_leaves': [2], # large num_leaves helps improve accuracy but might lead to over-fitting
              #'boosting_type' : ['gbdt'], # for better accuracy -> try dart
              #'objective' : ['binary'],
               # large max_bin helps improve accuracy but might slow down training progress
              #'colsample_bytree' : [1],
              'subsample'     : [1],
              #'reg_alpha' : [1],
              #'reg_lambda' : [2],
              #'scale_pos_weight' : [191],
              'max_depth': [10] ,
              'max_features': ['auto']
    }

# Búsqueda por grid search con validación cruzada
# ==============================================================================
grid_GBC_os = GridSearchCV(
        estimator  = GradientBoostingClassifier(random_state=42),
        param_grid = param_grid,
        scoring    = 'recall',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits=100, n_repeats=1, random_state=123), 
        refit      = True,
        verbose    = 0,
        return_train_score = True
       )

#grid_GBC_sw.fit(X = X_train_ub, y = y_train_ub , sample_weight = sample_weight[y_train_ub.values])
grid_GBC_os.fit(X = X_train_os, y = y_train_os)

# Resultados
# ==============================================================================
print("Resultados GridSearch ---->>> GradientBoostingClassifier")
resultados_os = pd.DataFrame(grid_GBC_os.cv_results_)
resultados_os.filter(regex = '(param*|mean_t|std_t)') \
    .drop(columns = 'params') \
    .sort_values('mean_test_score', ascending = False) \
    .head(4)
# Mejores hiperparámetros por validación cruzada GradientBoostingClassifier
# ==============================================================================
print("----------------------------------------")
print("Mejores hiperparámetros encontrados (cv) GradientBoostingClassifier")
print("----------------------------------------")
print(grid_GBC_os.best_params_, ":", grid_GBC_os.best_score_, grid_GBC_os.scoring)

# Guardamos el mejor modelo
modelo_GBC_os = grid_GBC_os.best_estimator_
#Accuracy del modelo
GBC_accuracy_os = grid_GBC_os.best_score_
# Out:
# Resultados GridSearch ---->>> GradientBoostingClassifier
# ----------------------------------------
# Mejores hiperparámetros encontrados (cv) GradientBoostingClassifier
# ----------------------------------------
# {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 500, 'subsample': 1} : 1.0 recall

# %%
cv_GBC_bbc = cross_validate(modelo_GBC_os, X_ub, y, cv=100)
sorted(cv_GBC_bbc.keys())
cv_GBC_bbc['test_score']
# Out:
# array([0.94      , 0.92      , 0.92      , 0.92      , 0.94      ,
#        0.94      , 0.94      , 0.94      , 0.94      , 0.94      ,
#        0.94      , 0.94      , 0.92      , 0.92      , 0.94      ,
#        0.92      , 0.94      , 0.92      , 0.94      , 0.94      ,
#        0.94      , 0.94      , 0.94      , 0.94      , 0.94      ,
#        0.92      , 0.94      , 0.92      , 0.94      , 0.94      ,
#        0.94      , 0.94      , 0.94      , 0.94      , 0.92      ,
#        0.96      , 0.96      , 0.94      , 0.92      , 0.94      ,
#        0.94      , 0.94      , 0.94      , 0.92      , 0.94      ,
#        0.9       , 0.92      , 0.94      , 0.94      , 0.96      ,
#        0.98      , 0.96      , 0.96      , 0.94      , 0.96      ,
#        0.96      , 0.94      , 0.96      , 0.96      , 0.96      ,
#        0.96      , 0.96      , 0.96      , 0.96      , 0.94      ,
#        0.96      , 0.98      , 0.94      , 0.94      , 0.96      ,
#        0.96      , 0.94      , 0.96      , 0.96      , 0.96      ,
#        0.96      , 0.96      , 0.96      , 0.96      , 0.96      ,
#        0.94      , 0.93877551, 0.95918367, 0.93877551, 0.97959184,
#        0.95918367, 0.93877551, 0.93877551, 0.95918367, 0.95918367,
#        0.93877551, 0.95918367, 0.95918367, 0.95918367, 0.93877551,
#        0.93877551, 0.95918367, 0.95918367, 0.93877551, 0.93877551])

# %%
# Accuracy cross_validation
cv_GBC_mean =sum(cv_GBC_bbc['test_score'])/len(cv_GBC_bbc['test_score'])

# %%
# Prediccion y evaluacion del modelo
y_pred_bbc= modelo_GBC_os.predict(X_test)
y_pred_train_bbc= modelo_GBC_os.predict(X_train_os)

#Accuracy del modelo
accuracy_test_predict_bbc= accuracy_score(y_test, y_pred_bbc)

#balanced_Accuracy del modelo
balanced_accuracy_test= balanced_accuracy_score(y_test, y_pred_bbc)

#Accuracy del train
accuracy_train_bbc = accuracy_score(y_train_os,y_pred_train_bbc)

print("")
print("Balanced_accuracy de test es: {:.2f} %".format(100 * balanced_accuracy_test))
print("")
print("El accuracy de test es: {:.2f} %".format(100 * accuracy_test_predict_bbc))
print("")
print("El accuracy del train es: {:.2f} %".format(100 * accuracy_train_bbc))
print("")
print("El overfitting del test y train es {:.2f} % ".format(((balanced_accuracy_test - accuracy_train_bbc)/balanced_accuracy_test) *100))
print("")
print("El accuracy del cross_validate es: {:.2f} %".format(100 * cv_GBC_mean))
print("")
print("El overfitting del cross_validate (test) y train es {:.2f} % ".format(((cv_GBC_mean - accuracy_train_bbc)/accuracy_test_predict_bbc) *100))
print("")
print("")

#definimos funciona para mostrar los resultados
print("Matriz de confusión")
print("")

Labels= 'No_Stroke', 'Stroke'

def mostrar_resultados(y_test, y_pred__bbc):
    conf_matrix = confusion_matrix(y_test, y_pred_bbc)
    plt.figure(figsize=(8, 8))
    sns.heatmap(conf_matrix, xticklabels=Labels, yticklabels=Labels, annot=True, fmt="d");
    plt.title("Matriz de confusión")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()
    print("")
    print("Reporte de Clasificación (test)")
    print("-------------------")
    print (classification_report(y_test, y_pred_bbc))
    
mostrar_resultados(y_test, y_pred_bbc)
print("")
print("Reporte de Clasificación (train)")
print("-------------------")
print (classification_report(y_train_os,y_pred_train_bbc))
print("")
# Out:
# Balanced_accuracy de test es: 49.68 %
#
# El accuracy de test es: 94.38 %
#
# El accuracy del train es: 100.00 %
#
# El overfitting del test y train es -101.28 %
#
# El accuracy del cross_validate es: 94.48 %
#
# El overfitting del cross_validate (test) y train es -5.85 %
#
#
# Matriz de confusión
# Reporte de Clasificación (test)
# -------------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       947
#            1       0.00      0.00      0.00        50
#
#     accuracy                           0.94       997
#    macro avg       0.47      0.50      0.49       997
# weighted avg       0.90      0.94      0.92       997
#
#
# Reporte de Clasificación (train)
# -------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3786
#            1       1.00      1.00      1.00      3786
#
#     accuracy                           1.00      7572
#    macro avg       1.00      1.00      1.00      7572
# weighted avg       1.00      1.00      1.00      7572

# %% [markdown]
# # LGBM con `Random_Over_Sampler`

# %%
param_grid = {'learning_rate' : [1],
              'n_estimators'  : [500],
               'num_leaves': [2], # large num_leaves helps improve accuracy but might lead to over-fitting
              'boosting_type' : ['gbdt'], # for better accuracy -> try dart
              'objective' : ['binary'],
               # large max_bin helps improve accuracy but might slow down training progress
              'colsample_bytree' : [1],
              'subsample'     : [1],
              'reg_alpha' : [1],
              'reg_lambda' : [2],
              'scale_pos_weight' : [191],
              
    }

grid_LGBMC_os = GridSearchCV(
        estimator  = LGBMClassifier(random_state=42),
        param_grid = param_grid,
        scoring    = 'recall',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits=100, n_repeats=1, random_state=123), 
        refit      = True,
        verbose    = 0,
        return_train_score = True
       )

grid_LGBMC_os.fit(X = X_train_os, y = y_train_os)

# Resultados
# ==============================================================================
print("Resultados GridSearch ---->>> GradientBoostingClassifier")
resultados_os = pd.DataFrame(grid_LGBMC_os.cv_results_)
resultados_os.filter(regex = '(param*|mean_t|std_t)') \
    .drop(columns = 'params') \
    .sort_values('mean_test_score', ascending = False) \
    .head(4)
# Mejores hiperparámetros por validación cruzada GradientBoostingClassifier
# ==============================================================================
print("----------------------------------------")
print("Mejores hiperparámetros encontrados (cv) GradientBoostingClassifier")
print("----------------------------------------")
print(grid_LGBMC_os.best_params_, ":", grid_LGBMC_os.best_score_, grid_LGBMC_os.scoring)

# Guardamos el mejor modelo
modelo_LGBMC_os = grid_LGBMC_os.best_estimator_
#Accuracy del modelo
LGBMC_accuracy_os = grid_LGBMC_os.best_score_
# Out:
# Resultados GridSearch ---->>> GradientBoostingClassifier
# ----------------------------------------
# Mejores hiperparámetros encontrados (cv) GradientBoostingClassifier
# ----------------------------------------
# {'boosting_type': 'gbdt', 'colsample_bytree': 1, 'learning_rate': 1, 'n_estimators': 500, 'num_leaves': 2, 'objective': 'binary', 'reg_alpha': 1, 'reg_lambda': 2, 'scale_pos_weight': 191, 'subsample': 1} : 1.0 recall

# %%
cv_LGBMC_os = cross_validate(modelo_LGBMC_os, X_ub, y, cv=100)
sorted(cv_LGBMC_os.keys())
cv_LGBMC_os['test_score']
# Out:
# array([0.88      , 0.88      , 0.82      , 0.22      , 0.32      ,
#        0.12      , 0.82      , 0.28      , 0.1       , 0.88      ,
#        0.38      , 0.84      , 0.86      , 0.12      , 0.7       ,
#        0.14      , 0.86      , 0.8       , 0.84      , 0.8       ,
#        0.24      , 0.86      , 0.18      , 0.78      , 0.8       ,
#        0.9       , 0.28      , 0.84      , 0.34      , 0.9       ,
#        0.82      , 0.96      , 0.86      , 0.74      , 0.32      ,
#        0.82      , 0.84      , 0.88      , 0.84      , 0.8       ,
#        0.2       , 0.8       , 0.14      , 0.84      , 0.18      ,
#        0.92      , 0.84      , 0.26      , 0.16      , 0.94      ,
#        0.84      , 0.84      , 0.26      , 0.86      , 0.86      ,
#        0.9       , 0.3       , 0.92      , 0.92      , 0.3       ,
#        0.24      , 0.86      , 0.86      , 0.24      , 0.3       ,
#        0.84      , 0.04      , 0.82      , 0.22      , 0.88      ,
#        0.24      , 0.76      , 0.16      , 0.9       , 0.84      ,
#        0.64      , 0.28      , 0.9       , 0.06      , 0.18      ,
#        0.12      , 0.83673469, 0.95918367, 0.89795918, 0.04081633,
#        0.79591837, 0.91836735, 0.83673469, 0.89795918, 0.87755102,
#        0.83673469, 0.89795918, 0.85714286, 0.91836735, 0.85714286,
#        0.32653061, 0.87755102, 0.87755102, 0.16326531, 0.83673469])

# %%
# Accuracy cross_validation
cv_LGBMC_mean =sum(cv_LGBMC_os['test_score'])/len(cv_LGBMC_os['test_score'])

# %%
# Prediccion y evaluacion del modelo
y_pred_bbc= modelo_LGBMC_os.predict(X_test)
y_pred_train_bbc= modelo_LGBMC_os.predict(X_train_os)

#Accuracy del modelo
accuracy_test_predict_bbc= accuracy_score(y_test, y_pred_bbc)

#balanced_Accuracy del modelo
balanced_accuracy_test= balanced_accuracy_score(y_test, y_pred_bbc)

#Accuracy del train
accuracy_train_bbc = accuracy_score(y_train_os,y_pred_train_bbc)

print("")
print("Balanced_accuracy de test es: {:.2f} %".format(100 * balanced_accuracy_test))
print("")
print("El accuracy de test es: {:.2f} %".format(100 * accuracy_test_predict_bbc))
print("")
print("El accuracy del train es: {:.2f} %".format(100 * accuracy_train_bbc))
print("")
print("El overfitting del test y train es {:.2f} % ".format(((balanced_accuracy_test - accuracy_train_bbc)/balanced_accuracy_test) *100))
print("")
print("El accuracy del cross_validate es: {:.2f} %".format(100 * cv_LGBMC_mean))
print("")
print("El overfitting del cross_validate (test) y train es {:.2f} % ".format(((cv_LGBMC_mean - accuracy_train_bbc)/accuracy_test_predict_bbc) *100))
print("")
print("")

#definimos funciona para mostrar los resultados
print("Matriz de confusión")
print("")

Labels= 'No_Stroke', 'Stroke'

def mostrar_resultados(y_test, y_pred__bbc):
    conf_matrix = confusion_matrix(y_test, y_pred_bbc)
    plt.figure(figsize=(8, 8))
    sns.heatmap(conf_matrix, xticklabels=Labels, yticklabels=Labels, annot=True, fmt="d");
    plt.title("Matriz de confusión")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()
    print("")
    print("Reporte de Clasificación (test)")
    print("-------------------")
    print (classification_report(y_test, y_pred_bbc))
    
mostrar_resultados(y_test, y_pred_bbc)
print("")
print("Reporte de Clasificación (train)")
print("-------------------")
print (classification_report(y_train_os,y_pred_train_bbc))
print("")
# Out:
# Balanced_accuracy de test es: 73.34 %
#
# El accuracy de test es: 51.15 %
#
# El accuracy del train es: 73.72 %
#
# El overfitting del test y train es -0.52 %
#
# El accuracy del cross_validate es: 62.83 %
#
# El overfitting del cross_validate (test) y train es -21.29 %
#
#
# Matriz de confusión
# Reporte de Clasificación (test)
# -------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.49      0.65       947
#            1       0.09      0.98      0.17        50
#
#     accuracy                           0.51       997
#    macro avg       0.54      0.73      0.41       997
# weighted avg       0.95      0.51      0.63       997
#
#
# Reporte de Clasificación (train)
# -------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.47      0.64      3786
#            1       0.66      1.00      0.79      3786
#
#     accuracy                           0.74      7572
#    macro avg       0.83      0.74      0.72      7572
# weighted avg       0.83      0.74      0.72      7572

# %%
from sklearn.metrics import balanced_accuracy_score
def bagging(models):
    list_bbc=[]
    list_model=[]
    for indx,model in enumerate(models):
        # Instanciamos el BalancedBaggingClassifier
        bbc = BalancedBaggingClassifier(base_estimator=model,
                                sampling_strategy='auto',
                                replacement=False,
                                random_state=0)

        # Grid de hiperparámetros evaluados
        # ==============================================================================
        bc_params = {"base_estimatormax_depth": [3,5,10,20],
          "base_estimatormax_features": [None, "auto"],
          "base_estimatormin_samples_leaf": [1, 3, 5, 7, 10],
          "base_estimatormin_samples_split": [2, 5, 7],
          'bootstrap_features': [False, True],
          'max_features': [0.5, 0.7, 1.0],
          'max_samples': [0.5, 0.7, 1.0],
          'n_estimators': [2, 5, 10, 20],
        }


        # Búsqueda por grid search con validación cruzada
        # ==============================================================================
        grid_bbc = GridSearchCV(
            estimator  = bbc,
            param_grid = bc_params,
            scoring    = 'accuracy',
            n_jobs     = multiprocessing.cpu_count() - 1,
            cv         = RepeatedKFold(n_splits=3, n_repeats=1, random_state=123), 
            refit      = True,
            verbose    = 0,
            return_train_score = True
           )
        
        bbc_train=grid_bbc.fit(X = X_train, y = y_train)
        y_pred= grid_acc.predict(X_test)
        y_pred_train= grid_acc.predict(X_train)
        modelo = grid_acc.best_estimator_
        #Accuracy del modelo
        accuracy_model = grid_acc.best_score_
        accuracy_test= accuracy_score(y_test, y_pred)
        accuracy_train = accuracy_score(y_train,y_pred_train)
        balaced_acc = balanced_accuracy_score(y_test, y_pred)
        overffiting_acc= np.abs((( balaced_acc - accuracy_train)/balaced_acc) *100)
        # Metricas recall_score y f1_score
        recall = recall_score(y_test, y_pred)
        f1= f1_score(y_test, y_pred)
        precission =precision_score(y_test, y_pred)
        bal_accuracy = balanced_accuracy_score(y_test, y_pred)                    
        result.iloc[row,1] = accuracy_model
        result.iloc[row,2]=  accuracy_test
        result.iloc[row,3]=  accuracy_train
        result.iloc[row,4]=  overffiting_acc
        result.iloc[row,5] = recall
        result.iloc[row,6] = f1
        result.iloc[row,7] = precission
        result.iloc[row,8] = bal_accuracy
        result.iloc[row,9] = roc_auc_score(y_test, y_pred)
        
        row += 1
        col_grid +=1
        list_model.append(modelo)
        result.head()
        result.to_csv(name)
        list_bbc.append(bbc_train)
    return (lista_bbc,list_model)
